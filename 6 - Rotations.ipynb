# %%
import numpy as np, cv2

# %% [markdown]
# # Rotation Matrix

# %%
from IPython.display import Image

# %%
Image('tutorial images/rotation matrix.png')

# %% [markdown]
# ## cv2.getRotationMatrix2D((rotation_center_x, rotation_center_y), angle of rotation, scale)

# %% [markdown]
# #### scale:- meaning ratio of actual and rotated image

# %% [markdown]
# #### Remember angle of rotation is anticlockwise

# %%
import cv2, numpy as np
image = cv2.imread('my.JPG')
height, width = image.shape[:2]

#Divide by two to rotate the image around its center
#we assume centre of image is width /2 and height / 2
rotation_matrix = cv2.getRotationMatrix2D((width / 2, height / 2), 180, 2)
rotated_image = cv2.warpAffine(image, rotation_matrix, (width, height))
cv2.imshow('Rotated Image', rotated_image)
#cv2.imwrite('Rotated Image.png', rotated_image)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # cv2.transpose(image)

# %% [markdown]
# ### Transpose of image

# %%
import cv2, numpy as np
image = cv2.imread('my.JPG')
image = cv2.transpose(image)
cv2.imshow('Transposed Image', image)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# ### ^^it converts width -> height and height -> width
